# %%
import pandas as pd
Telkomsel = pd.read_csv(r'C:\Users\fickysag\Desktop\TDSA\churn.csv')
Telkomsel.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
Telkomsel.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# class                            0
# dtype: int64

# %%
Telkomsel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %%
Telkomsel.sample(n=10, random_state=10)
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 245      40              22        408           188                   0
# 4493     46              83        510          3540                   0
# 4583     21             104        415          4068                   0
# 2242      5             192        415          3875                   0
# 3407      5              93        415          1000                   0
# 807      10              56        415          4723                   0
# 693      31              92        510          4924                   0
# 515      13             148        510          4941                   0
# 3224     15             115        415          2269                   0
# 549      36             121        408          1916                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# 245                 0                      0              110.3
# ...

# %%
Telkomsel["account_length"].mean()
# Out:
# 100.2586

# %%
#how many times mostly churn customer call customer service

import statistics as st

# %%
Telkomsel.corr(method='pearson').head(5)
# Out:
#                        state  account_length  area_code  phone_number  \
# state               1.000000        0.010334   0.013858      0.017054
# account_length      0.010334        1.000000  -0.018054      0.004918
# area_code           0.013858       -0.018054   1.000000     -0.011648
# phone_number        0.017054        0.004918  -0.011648      1.000000
# international_plan  0.007422        0.014681   0.032107      0.010463
#
#                     international_plan  voice_mail_plan  \
# state                         0.007422        -0.030075
# account_length                0.014681        -0.006650
# area_code                     0.032107        -0.003006
# phone_number                  0.010463         0.014384
# international_plan            1.000000         0.009054
#
#                     number_vmail_messages  total_day_minutes  total_day_calls  \
# state                           -0.027282           0.007334        -0.008166
# ...

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %%
churn = Telkomsel[Telkomsel['class'] == 1]
churn.head(5)
churn ["state"].value_counts().head(5)
# Out:
# 31    28
# 43    26
# 47    24
# 49    22
# 20    21
# Name: state, dtype: int64

# %%
churn = Telkomsel[Telkomsel['class'] == 1]
churn.count()
# Out:
# state                            707
# account_length                   707
# area_code                        707
# phone_number                     707
# international_plan               707
# voice_mail_plan                  707
# number_vmail_messages            707
# total_day_minutes                707
# total_day_calls                  707
# total_day_charge                 707
# total_eve_minutes                707
# total_eve_calls                  707
# total_eve_charge                 707
# total_night_minutes              707
# total_night_calls                707
# total_night_charge               707
# total_intl_minutes               707
# total_intl_calls                 707
# total_intl_charge                707
# number_customer_service_calls    707
# class                            707
# dtype: int64

# %%
# Average Length for Churned customer
churn.mean()
# Out:
# state                              26.251768
# account_length                    102.332390
# area_code                         437.971711
# phone_number                     2543.499293
# international_plan                  0.281471
# voice_mail_plan                     0.144272
# number_vmail_messages               4.496464
# total_day_minutes                 207.870580
# total_day_calls                   100.817539
# total_day_charge                   35.338416
# total_eve_minutes                 211.757850
# total_eve_calls                    99.884017
# total_eve_charge                   17.999562
# total_night_minutes               206.078218
# total_night_calls                  99.575672
# total_night_charge                  9.273607
# total_intl_minutes                 10.692362
# total_intl_calls                    4.151344
# total_intl_charge                   2.887426
# number_customer_service_calls       2.254597
# class                               1.000000
# ...

# %%
st.mean(churn.account_length)
# Out:
# 102.33239038189534

# %%
st.mean(churn.number_customer_service_calls)
# Out:
# 2.2545968882602545

# %%
st.mode(churn.total_day_calls)
# Out:
# 106

# %%
churn ["area_code"].value_counts().head(10)
# Out:
# 415    346
# 510    184
# 408    177
# Name: area_code, dtype: int64

# %%
churn ["state"].value_counts().head(15)
# Out:
# 31    28
# 43    26
# 47    24
# 49    22
# 20    21
# 26    21
# 34    20
# 23    20
# 21    19
# 22    18
# 16    18
# 37    18
# 25    17
# 19    17
# 33    17
# Name: state, dtype: int64

# %%
churn[['number_customer_service_calls','total_day_calls','total_intl_calls']].mean().round(2)
# Out:
# number_customer_service_calls      2.25
# total_day_calls                  100.82
# total_intl_calls                   4.15
# dtype: float64

# %%
not_churn = Telkomsel[Telkomsel['class'] == 0]
not_churn.head(5)
not_churn ["state"].value_counts().head(5)
# Out:
# 49    136
# 45    112
# 1     111
# 13    105
# 23    105
# Name: state, dtype: int64

# %%
not_churn[['number_customer_service_calls','total_day_calls','total_intl_calls']].mean().round(2)
# Out:
# number_customer_service_calls     1.46
# total_day_calls                  99.90
# total_intl_calls                  4.48
# dtype: float64
